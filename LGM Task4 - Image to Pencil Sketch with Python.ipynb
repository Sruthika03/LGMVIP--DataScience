# %% [markdown]
# # LetsGrowMore - Beginner Level Task - 4

# %% [markdown]
# ### Image to Pencil Sketch with Python

# %% [markdown]
# #### DESCRIPTION

# %% [markdown]
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is inverting the grayscale image also called as negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# #### REFERENCE PROVIDED

# %% [markdown]
# https://thecleverprogrammer.com/2020/09/30/pencil-sketch-with-python/

# %% [markdown]
# ### 1) Installing The Required Module/Library

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 2) Importing The Necessary Libraries

# %%
import cv2
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# ### 3) Reading The Image

# %%
my_img = cv2.imread("msd.jpg")
my_img = cv2.cvtColor(my_img,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(6,6))
plt.imshow(my_img)
plt.axis("off")
plt.title("\nMS Dhoni Original Image\n")
plt.show()

# %% [markdown]
# ### 4) Converting The Original Image To GreyScale

# %%
grey_img = cv2.cvtColor(my_img, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(6,6))
plt.imshow(grey_img, cmap="gray")
plt.axis("off")
plt.title("\nMS Dhoni Gray Scale Image\n")
plt.show()

# %% [markdown]
# ### 5) Inverting The GreyScale Image

# %%
inverted_img = cv2.bitwise_not(grey_img)
plt.figure(figsize=(6,6))
plt.imshow(inverted_img, cmap="gray")
plt.axis("off")
plt.title("\nMSD Inverted Image\n")
plt.show()

# %% [markdown]
# ### 6) Blurring The Image Using Gaussian Function In OpenCV

# %%
smoothened_img = cv2.GaussianBlur(inverted_img, (21, 21), sigmaX=0, sigmaY=0)
smoothened_img
# Out:
# array([[157, 157, 158, ..., 110, 110, 110],
#        [157, 157, 158, ..., 109, 109, 109],
#        [157, 157, 158, ..., 106, 107, 107],
#        ...,
#        [ 75,  75,  75, ..., 105, 105, 105],
#        [ 75,  75,  75, ..., 101, 101, 101],
#        [ 75,  75,  75, ..., 100, 100, 100]], dtype=uint8)

# %%
plt.figure(figsize=(6,6))
plt.imshow(smoothened_img,cmap="gray")
plt.axis("off")
plt.title("\nMSD Smoothened Image\n")
plt.show()

# %% [markdown]
# ### 7) Inverting The Blurred Image

# %%
final_output = cv2.divide(grey_img, 255 - smoothened_img , scale=255)
plt.figure(figsize=(6,6))
plt.imshow(final_output,cmap="gray")
plt.axis("off")
plt.title("\nMSD Final Pencil Sketch Image\n")
plt.show()

# %% [markdown]
# ### 8) Viewing Both The Images For Comparison

# %%
plt.figure(figsize=(20,20))
plt.subplot(1,5,1)
plt.imshow(my_img)
plt.axis("off")
plt.title("\nMSD - Original Image\n")
plt.subplot(1,5,2)
plt.imshow(final_output,cmap="gray")
plt.axis("off")
plt.title("\nMSD - Pencil Sketch\n")
plt.show()

# %% [markdown]
# ### CONCLUSION

# %% [markdown]
# Using, the provided reference source and description, an image was used for pencil sketching in python programatically by following the necessary steps using Gaussian function.
